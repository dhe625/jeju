# %%
import pandas as pd

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/6월/티맵 OD data_0601_0605.csv', 
                   delimiter = ',')
data_0601_0605 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/6월/티맵 OD data_0606_0610.csv', 
                   delimiter = ',')
data_0606_0610 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/6월/티맵 OD data_0611_0615.csv', 
                   delimiter = ',')
data_0611_0615 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/6월/티맵 OD data_0616_0620.csv', 
                   delimiter = ',')
data_0616_0620 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/6월/티맵 OD data_0621_0625.csv', 
                   delimiter = ',')
data_0621_0625 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/6월/티맵 OD data_0626_0630.csv', 
                   delimiter = ',')
data_0626_0630 = data[data['cate_name_b'] == '시장']

# %%
june = pd.concat([data_0601_0605, data_0606_0610, data_0611_0615, data_0616_0620, data_0621_0625, data_0626_0630],
               axis = 0)
# Out:
#         std_ym   std_ymd  arrival_hour local_user  sex  age           org  \
# 311     202106  20210601             8    foreign  NaN  NaN  Grid863_2849
# 342     202106  20210601             8    foreign  NaN  NaN  Grid890_2844
# 615     202106  20210601             9    foreign  NaN  NaN  Grid875_2851
# 647     202106  20210601             9    foreign  NaN  NaN  Grid891_2839
# 682     202106  20210601             9    foreign  NaN  NaN  Grid956_2825
# ...        ...       ...           ...        ...  ...  ...           ...
# 446526  202106  20210630            21    foreign  NaN  NaN  Grid865_2851
# 446557  202106  20210630            21    foreign    M  30s  Grid910_2977
# 446569  202106  20210630            21    foreign    M  50s  Grid964_2846
# 446616  202106  20210630            22    foreign    M  40s  Grid883_2984
# 446631  202106  20210630            23    foreign  NaN  NaN  Grid867_2848
#
#                 dest  catecode_a  catecode_b  catecode_c  catecode_d  \
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/7월/티맵 OD data_0701_0705.csv', 
                   delimiter = ',')
data_0701_0705 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/7월/티맵 OD data_0706_0710.csv', 
                   delimiter = ',')
data_0706_0710 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/7월/티맵 OD data_0711_0715.csv', 
                   delimiter = ',')
data_0711_0715 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/7월/티맵 OD data_0716_0720.csv', 
                   delimiter = ',')
data_0716_0720 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/7월/티맵 OD data_0721_0725.csv', 
                   delimiter = ',')
data_0721_0725 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/7월/티맵 OD data_0726_0731.csv', 
                   delimiter = ',')
data_0726_0731 = data[data['cate_name_b'] == '시장']

# %%
july = pd.concat([data_0701_0705, data_0706_0710, data_0711_0715, data_0716_0720, data_0721_0725, data_0726_0731],
               axis = 0)

july
# Out:
#         std_ym   std_ymd  arrival_hour local_user  sex  age           org  \
# 309     202107  20210701             8    foreign  NaN  NaN  Grid767_2894
# 345     202107  20210701             8    foreign  NaN  NaN  Grid870_2846
# 409     202107  20210701             8    foreign    F  50s  Grid874_2838
# 706     202107  20210701             9    foreign  NaN  NaN  Grid892_2851
# 744     202107  20210701             9    foreign  NaN  NaN  Grid989_2819
# ...        ...       ...           ...        ...  ...  ...           ...
# 607326  202107  20210731            20    foreign  NaN  NaN  Grid873_2845
# 607331  202107  20210731            20    foreign  NaN  NaN  Grid878_2847
# 607447  202107  20210731            21    foreign  NaN  NaN  Grid853_2851
# 607477  202107  20210731            21    foreign    F  30s  Grid885_2841
# 607522  202107  20210731            21      local    M  40s  Grid868_2851
#
#                 dest  catecode_a  catecode_b  catecode_c  catecode_d  \
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/8월/티맵 OD data_0801_0805.csv', 
                   delimiter = ',')
data_0801_0805 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/8월/티맵 OD data_0806_0810.csv', 
                   delimiter = ',')
data_0806_0810 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/8월/티맵 OD data_0811_0815.csv', 
                   delimiter = ',')
data_0811_0815 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/8월/티맵 OD data_0816_0820.csv', 
                   delimiter = ',')
data_0816_0820 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/8월/티맵 OD data_0821_0825.csv', 
                   delimiter = ',')
data_0821_0825 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/8월/티맵 OD data_0826_0831.csv', 
                   delimiter = ',')
data_0826_0831 = data[data['cate_name_b'] == '시장']

# %%
august = pd.concat([data_0801_0805, data_0806_0810, data_0811_0815, data_0816_0820, data_0821_0825, data_0826_0831],
               axis = 0)

august
# Out:
#         std_ym   std_ymd  arrival_hour local_user  sex  age            org  \
# 242     202108  20210801             7    foreign  NaN  NaN  Grid1060_2835
# 316     202108  20210801             7    foreign    M  30s   Grid787_2879
# 334     202108  20210801             7    foreign    M  40s   Grid865_2842
# 415     202108  20210801             8    foreign  NaN  NaN   Grid790_2868
# 443     202108  20210801             8    foreign  NaN  NaN   Grid867_2848
# ...        ...       ...           ...        ...  ...  ...            ...
# 480153  202108  20210831            18      local    M  20s   Grid888_2838
# 480197  202108  20210831            19    foreign  NaN  NaN   Grid874_2995
# 480256  202108  20210831            19    foreign    M  40s   Grid770_2900
# 480265  202108  20210831            19    foreign    M  40s   Grid957_2826
# 480397  202108  20210831            21    foreign  NaN  NaN   Grid882_2840
#
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/9월/티맵 OD data_0901_0905.csv', 
                   delimiter = ',')
data_0901_0905 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/9월/티맵 OD data_0906_0910.csv', 
                   delimiter = ',')
data_0906_0910 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/9월/티맵 OD data_0911_0915.csv', 
                   delimiter = ',')
data_0911_0915 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/9월/티맵 OD data_0916_0920.csv', 
                   delimiter = ',')
data_0916_0920 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/9월/티맵 OD data_0921_0925.csv', 
                   delimiter = ',')
data_0921_0925 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/9월/티맵 OD data_0926_0930.csv', 
                   delimiter = ',')
data_0926_0930 = data[data['cate_name_b'] == '시장']

# %%
september = pd.concat([data_0901_0905, data_0906_0910, data_0911_0915, data_0916_0920, data_0921_0925, data_0926_0930],
               axis = 0)

september
# Out:
#         std_ym   std_ymd  arrival_hour local_user  sex  age           org  \
# 43      202109  20210901             4    foreign    M  50s  Grid908_2991
# 156     202109  20210901             7    foreign  NaN  NaN  Grid908_2966
# 263     202109  20210901             8    foreign  NaN  NaN  Grid826_2855
# 426     202109  20210901             8      local  NaN  NaN  Grid957_2828
# 551     202109  20210901             9    foreign  NaN  NaN  Grid875_2837
# ...        ...       ...           ...        ...  ...  ...           ...
# 392896  202109  20210930            18    foreign    M  40s  Grid909_2987
# 393008  202109  20210930            19    foreign    F  40s  Grid906_2992
# 393012  202109  20210930            19    foreign    F  50s  Grid910_2987
# 393020  202109  20210930            19    foreign    M  30s  Grid807_2862
# 393106  202109  20210930            20    foreign  NaN  NaN  Grid885_2840
#
#                 dest  catecode_a  catecode_b  catecode_c  catecode_d  \
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/10월/티맵 OD data_1001_1005.csv', 
                   delimiter = ',')
data_1001_1005 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/10월/티맵 OD data_1006_1010.csv', 
                   delimiter = ',')
data_1006_1010 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/10월/티맵 OD data_1011_1015.csv', 
                   delimiter = ',')
data_1011_1015 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/10월/티맵 OD data_1016_1020.csv', 
                   delimiter = ',')
data_1016_1020 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/10월/티맵 OD data_1021_1025.csv', 
                   delimiter = ',')
data_1021_1025 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/10월/티맵 OD data_1026_1031.csv', 
                   delimiter = ',')
data_1026_1031 = data[data['cate_name_b'] == '시장']

# %%
october = pd.concat([data_1001_1005, data_1006_1010, data_1011_1015, data_1016_1020, data_1021_1025, data_1026_1031],
               axis = 0)

october
# Out:
#         std_ym   std_ymd  arrival_hour local_user  sex  age            org  \
# 57      202110  20211001             2      local  NaN  NaN   Grid947_2848
# 414     202110  20211001             8    foreign    M  50s   Grid873_2844
# 469     202110  20211001             8      local  NaN  NaN   Grid883_2844
# 673     202110  20211001             9    foreign  NaN  NaN   Grid889_2839
# 773     202110  20211001             9    foreign    M  30s   Grid727_2973
# ...        ...       ...           ...        ...  ...  ...            ...
# 570928  202110  20211031            20    foreign    M  40s  Grid1025_2942
# 570930  202110  20211031            20    foreign    M  40s   Grid794_2870
# 570935  202110  20211031            20    foreign    M  40s   Grid885_2841
# 570980  202110  20211031            21    foreign  NaN  NaN   Grid836_2987
# 571013  202110  20211031            21    foreign    M  40s   Grid893_2851
#
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/11월/티맵 OD data_1101_1105.csv', 
                   delimiter = ',')
data_1101_1105 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/11월/티맵 OD data_1106_1110.csv', 
                   delimiter = ',')
data_1106_1110 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/11월/티맵 OD data_1111_1115.csv', 
                   delimiter = ',')
data_1111_1115 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/11월/티맵 OD data_1116_1120.csv', 
                   delimiter = ',')
data_1116_1120 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/11월/티맵 OD data_1121_1125.csv', 
                   delimiter = ',')
data_1121_1125 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/11월/티맵 OD data_1126_1130.csv', 
                   delimiter = ',')
data_1126_1130 = data[data['cate_name_b'] == '시장']

# %%
november = pd.concat([data_1101_1105, data_1106_1110, data_1111_1115, data_1116_1120, data_1121_1125, data_1126_1130],
               axis = 0)

november
# Out:
#         std_ym   std_ymd  arrival_hour local_user  sex  age           org  \
# 259     202111  20211101             7    foreign  NaN  NaN  Grid894_2835
# 261     202111  20211101             7    foreign  NaN  NaN  Grid909_2987
# 295     202111  20211101             7    foreign    M  40s  Grid761_2914
# 330     202111  20211101             7      local  NaN  NaN  Grid877_2842
# 345     202111  20211101             7      local  NaN  NaN  Grid946_2822
# ...        ...       ...           ...        ...  ...  ...           ...
# 417062  202111  20211130            19    foreign    F  40s  Grid885_2986
# 417078  202111  20211130            19    foreign    M  40s  Grid889_2841
# 417139  202111  20211130            20    foreign  NaN  NaN  Grid861_2851
# 417145  202111  20211130            20    foreign  NaN  NaN  Grid880_2844
# 417159  202111  20211130            20    foreign    F  40s  Grid877_2845
#
#                 dest  catecode_a  catecode_b  catecode_c  catecode_d  \
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/12월/티맵 OD data_1201_1205.csv', 
                   delimiter = ',')
data_1201_1205 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/12월/티맵 OD data_1206_1210.csv', 
                   delimiter = ',')
data_1206_1210 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/12월/티맵 OD data_1211_1215.csv', 
                   delimiter = ',')
data_1211_1215 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/12월/티맵 OD data_1216_1220.csv', 
                   delimiter = ',')
data_1216_1220 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/12월/티맵 OD data_1221_1225.csv', 
                   delimiter = ',')
data_1221_1225 = data[data['cate_name_b'] == '시장']

data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/12월/티맵 OD data_1226_1231.csv', 
                   delimiter = ',')
data_1226_1231 = data[data['cate_name_b'] == '시장']

# %%
december = pd.concat([data_1201_1205, data_1206_1210, data_1211_1215, data_1216_1220, data_1221_1225, data_1226_1231],
               axis = 0)

december
# Out:
#         std_ym   std_ymd  arrival_hour local_user  sex age_group          org  \
# 547     202112  20211201             5      local    M       70s  Grid261_510
# 1036    202112  20211201             7    foreign  NaN       NaN  Grid276_365
# 1361    202112  20211201             7      local  NaN       NaN  Grid237_383
# 1395    202112  20211201             7      local  NaN       NaN  Grid255_363
# 1430    202112  20211201             7      local  NaN       NaN  Grid269_505
# ...        ...       ...           ...        ...  ...       ...          ...
# 425644  202112  20211231            22    foreign  NaN       NaN  Grid231_376
# 425715  202112  20211231            22    foreign  NaN       NaN  Grid244_373
# 425891  202112  20211231            22    foreign    M       30s  Grid229_384
# 425906  202112  20211231            22    foreign    M       30s  Grid241_370
# 425937  202112  20211231            22    foreign    M       40s  Grid160_511
#
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/1월/tmap_OD_202101.csv', 
                   delimiter = '|')
january = data[data['DEST_CLASS_CD_2'] == 17]

january
# Out:
#         STD_YM   STD_YMD    ETC GENDER  AGE          ORG         DEST  \
# 124     202101  20210101  local      M   20  Grid240_376  Grid407_357
# 289     202101  20210101  local      M   30  Grid121_469  Grid125_527
# 662     202101  20210101  local      M   30  Grid238_369  Grid254_362
# 1838    202101  20210101  local      M   40  Grid271_514  Grid271_511
# 1970    202101  20210101  local      M   40  Grid319_494  Grid229_373
# ...        ...       ...    ...    ...  ...          ...          ...
# 476790  202101  20210131  visit      W   60  Grid152_399  Grid176_388
# 476898  202101  20210131  visit      W   60  Grid308_501  Grid271_511
# 476904  202101  20210131  visit      W   60  Grid321_408  Grid271_511
# 476926  202101  20210131  visit      W   60  Grid377_479  Grid352_491
# 476947  202101  20210131  visit      W   70  Grid120_432  Grid136_415
#
#         DEST_HH  DEST_MM  TOTAL_TIME  DEST_CLASS_CD_1  DEST_CLASS_CD_2  \
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/2월/tmap_OD_202102.csv', 
                   delimiter = '|')
feburary = data[data['DEST_CLASS_CD_2'] == 17]

feburary
# Out:
#         STD_YM   STD_YMD    ETC GENDER  AGE          ORG         DEST  \
# 641     202102  20210201  local      M   30  Grid231_379  Grid254_364
# 715     202102  20210201  local      M   30  Grid237_375  Grid254_364
# 802     202102  20210201  local      M   30  Grid244_366  Grid231_375
# 829     202102  20210201  local      M   30  Grid246_373  Grid249_365
# 1032    202102  20210201  local      M   30  Grid263_365  Grid249_365
# ...        ...       ...    ...    ...  ...          ...          ...
# 656685  202102  20210228  visit      W   60  Grid173_489  Grid271_511
# 656717  202102  20210228  visit      W   60  Grid199_504  Grid203_507
# 656722  202102  20210228  visit      W   60  Grid201_506  Grid271_511
# 656927  202102  20210228  visit      W   60  Grid437_406  Grid271_510
# 656970  202102  20210228  visit      W   70  Grid240_501  Grid272_511
#
#         DEST_HH  DEST_MM  TOTAL_TIME  DEST_CLASS_CD_1  DEST_CLASS_CD_2  \
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/3월/tmap_OD_202103.csv', 
                   delimiter = '|')
march = data[data['DEST_CLASS_CD_2'] == 17]

march
# Out:
#         STD_YM   STD_YMD    ETC GENDER  AGE          ORG         DEST  \
# 62      202103  20210301  local      M   20  Grid215_503  Grid271_511
# 143     202103  20210301  local      M   20  Grid241_378  Grid254_364
# 342     202103  20210301  local      M   30  Grid133_518  Grid128_526
# 885     202103  20210301  local      M   30  Grid257_374  Grid231_375
# 952     202103  20210301  local      M   30  Grid262_395  Grid433_398
# ...        ...       ...    ...    ...  ...          ...          ...
# 785507  202103  20210331  visit      W   60  Grid273_512  Grid271_511
# 785636  202103  20210331  visit      W   60  Grid367_401  Grid381_431
# 785675  202103  20210331  visit      W   60  Grid404_358  Grid407_357
# 785690  202103  20210331  visit      W   60  Grid435_399  Grid271_511
# 785739  202103  20210331  visit      W   70  Grid229_373  Grid254_364
#
#         DEST_HH  DEST_MM  TOTAL_TIME  DEST_CLASS_CD_1  DEST_CLASS_CD_2  \
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/4월/tmap_OD_202104.csv', 
                   delimiter = '|')
april = data[data['DEST_CLASS_CD_2'] == 17]

april
# Out:
#         STD_YM   STD_YMD    ETC GENDER  AGE          ORG         DEST  \
# 236     202104  20210401  local      M   20  Grid264_386  Grid254_369
# 256     202104  20210401  local      M   20  Grid271_508  Grid271_511
# 363     202104  20210401  local      M   30  Grid127_525  Grid124_527
# 449     202104  20210401  local      M   30  Grid177_517  Grid214_516
# 568     202104  20210401  local      M   30  Grid219_392  Grid276_501
# ...        ...       ...    ...    ...  ...          ...          ...
# 913633  202104  20210430  visit      W   60  Grid331_449  Grid407_357
# 913714  202104  20210430  visit      W   70  Grid163_485  Grid206_510
# 913722  202104  20210430  visit      W   70  Grid192_502  Grid206_510
# 913734  202104  20210430  visit      W   70  Grid233_378  Grid235_388
# 913774  202104  20210430  visit      W   70  Grid289_412  Grid235_388
#
#         DEST_HH  DEST_MM  TOTAL_TIME  DEST_CLASS_CD_1  DEST_CLASS_CD_2  \
# ...

# %%
data = pd.read_csv('/Users/leedonghyeok/Desktop/data_jeju/내비게이션데이터/5월/tmap_OD_202105.csv', 
                   delimiter = '|')
may = data[data['DEST_CLASS_CD_2'] == 17]

may
# Out:
#         STD_YM   STD_YMD    ETC GENDER  AGE          ORG         DEST  \
# 273     202105  20210501  local      M   20  Grid262_380  Grid249_365
# 321     202105  20210501  local      M   20  Grid297_510  Grid271_511
# 378     202105  20210501  local      M   20  Grid407_363  Grid407_357
# 433     202105  20210501  local      M   30  Grid120_478  Grid124_527
# 531     202105  20210501  local      M   30  Grid150_400  Grid271_511
# ...        ...       ...    ...    ...  ...          ...          ...
# 971059  202105  20210531  visit      W   50  Grid395_468  Grid271_511
# 971252  202105  20210531  visit      W   60  Grid129_529  Grid128_526
# 971277  202105  20210531  visit      W   60  Grid152_522  Grid271_511
# 971371  202105  20210531  visit      W   60  Grid222_476  Grid271_511
# 971373  202105  20210531  visit      W   60  Grid222_508  Grid271_511
#
#         DEST_HH  DEST_MM  TOTAL_TIME  DEST_CLASS_CD_1  DEST_CLASS_CD_2  \
# ...

# %%
first_half = pd.concat([january, feburary, march, april, may])
second_half =  pd.concat([june, july, august, september, october, november, december])

market = pd.concat([first_half['DEST'],second_half['dest']])

selected_market = market.value_counts()

print(selected_market.head(5))
# Out:
# Grid888_2839    160055
# Grid908_2985    124324
# Grid254_364      34605
# Grid271_510      19832
# Grid870_2862     17028
# dtype: int64
